# %%
import requests
import json
import pandas as pd
import sqlite3

# Base URL for the listings endpoint
base_url = "https://www.athome.lu/portal/api/listings"

# This function will page through listings for a given price range.
def fetch_listings(price_gte, price_lte, page_size=200):
    listings = []
    page = 1
    while True:
        params = {
            "filters[price][gte]": str(price_gte),
            "filters[price][lte]": str(price_lte),
            "pagination[size]": page_size,
            "pagination[page]": page,
            "sort[createdAt]": "desc",
            "site": "athomelu"
        }
        print(f"Fetching page {page} for price range {price_gte}-{price_lte}...")
        response = requests.get(base_url, params=params)
        
        if response.status_code == 422:
            print("Received 422 Unprocessable Entity error; stopping pagination for this price range.")
            break
        elif response.status_code != 200:
            print(f"Error: Received status code {response.status_code} on page {page} for price range {price_gte}-{price_lte}.")
            break

        data = response.json().get("data", [])
        if not data:
            print("No more data returned; stopping pagination for this price range.")
            break

        listings.extend(data)
        # Save a simplified record for each listing
        for listing in data:
            price_results.append({
                "page": page,
                "price": listing.get("price"),
                "price_from": price_gte,
                "price_to": price_lte
            })
        print(f"Retrieved {len(data)} listings on page {page}.")
        page += 1
    return listings

# List to accumulate full listing objects and simplified price records.
all_listings = []
price_results = []

# Build the list of price ranges.
price_ranges = []

# 1. From 0 to 10,000 in steps of 1,000.
for p in range(0, 10000, 1000):
    price_ranges.append((p, p + 1000))

# 2. From 10,000 to 30,000 in steps of 10,000.
for p in range(10000, 30000, 10000):
    price_ranges.append((p, p + 10000))

# 3. From 30,000 to 10,000,000 in steps of 100,000.
for p in range(30000, 10000000, 100000):
    price_ranges.append((p, p + 100000))

print(f"Total price ranges to query: {len(price_ranges)}")

# Iterate over each price range and collect listings.
for (price_gte, price_lte) in price_ranges:
    listings = fetch_listings(price_gte, price_lte, page_size=200)
    if listings:
        all_listings.extend(listings)
    else:
        print(f"No listings found for price range {price_gte}-{price_lte}.")

# Save the raw JSON data for backup.
with open("athome_listings_raw.json", "w", encoding="utf-8") as f:
    json.dump(all_listings, f, indent=4)
print("\nRaw JSON data saved to 'athome_listings_raw.json'.")

# Save the simplified price data to CSV.
df_price = pd.DataFrame(price_results)
df_price.to_csv("price_selection.csv", index=False, encoding="utf-8")
print("Saved the price selection data to 'price_selection.csv'.")

# Normalize (flatten) the full JSON data.
df = pd.json_normalize(all_listings)
print("Data normalized. DataFrame shape:", df.shape)

# Convert complex types (lists, dicts) to JSON strings so SQLite can store them.
def convert_complex(val):
    if isinstance(val, (list, dict)):
        return json.dumps(val)
    return val

df = df.applymap(convert_complex)

# Save the flattened DataFrame to an SQLite database.
db_filename = "athome_listings.db"
conn = sqlite3.connect(db_filename)
df.to_sql("listings", conn, if_exists="replace", index=False)
conn.commit()
conn.close()

print(f"Flattened data saved to SQLite database '{db_filename}' in table 'listings'.")
# Out:
# Total price ranges to query: 112
# Fetching page 1 for price range 0-1000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 0-1000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 0-1000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 0-1000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 0-1000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 0-1000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 0-1000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 0-1000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 0-1000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 0-1000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 0-1000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 0-1000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 0-1000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 0-1000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 0-1000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 0-1000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 0-1000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 0-1000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 0-1000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 0-1000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 0-1000...
# Retrieved 200 listings on page 21.
# Fetching page 22 for price range 0-1000...
# Retrieved 200 listings on page 22.
# Fetching page 23 for price range 0-1000...
# Retrieved 200 listings on page 23.
# Fetching page 24 for price range 0-1000...
# Retrieved 200 listings on page 24.
# Fetching page 25 for price range 0-1000...
# Retrieved 200 listings on page 25.
# Fetching page 26 for price range 0-1000...
# Retrieved 200 listings on page 26.
# Fetching page 27 for price range 0-1000...
# Retrieved 200 listings on page 27.
# Fetching page 28 for price range 0-1000...
# Retrieved 200 listings on page 28.
# Fetching page 29 for price range 0-1000...
# Retrieved 200 listings on page 29.
# Fetching page 30 for price range 0-1000...
# Retrieved 200 listings on page 30.
# Fetching page 31 for price range 0-1000...
# Retrieved 200 listings on page 31.
# Fetching page 32 for price range 0-1000...
# Retrieved 200 listings on page 32.
# Fetching page 33 for price range 0-1000...
# Retrieved 55 listings on page 33.
# Fetching page 34 for price range 0-1000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1000-2000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1000-2000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1000-2000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 1000-2000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 1000-2000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 1000-2000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 1000-2000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 1000-2000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 1000-2000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 1000-2000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 1000-2000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 1000-2000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 1000-2000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 1000-2000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 1000-2000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 1000-2000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 1000-2000...
# Retrieved 83 listings on page 17.
# Fetching page 18 for price range 1000-2000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2000-3000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 2000-3000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 2000-3000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 2000-3000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 2000-3000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 2000-3000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 2000-3000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 2000-3000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 2000-3000...
# Retrieved 63 listings on page 9.
# Fetching page 10 for price range 2000-3000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3000-4000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 3000-4000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 3000-4000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 3000-4000...
# Retrieved 140 listings on page 4.
# Fetching page 5 for price range 3000-4000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4000-5000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 4000-5000...
# Retrieved 176 listings on page 2.
# Fetching page 3 for price range 4000-5000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5000-6000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 5000-6000...
# Retrieved 109 listings on page 2.
# Fetching page 3 for price range 5000-6000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 6000-7000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 6000-7000...
# Retrieved 32 listings on page 2.
# Fetching page 3 for price range 6000-7000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7000-8000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 7000-8000...
# Retrieved 52 listings on page 2.
# Fetching page 3 for price range 7000-8000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8000-9000...
# Retrieved 175 listings on page 1.
# Fetching page 2 for price range 8000-9000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 9000-10000...
# Retrieved 157 listings on page 1.
# Fetching page 2 for price range 9000-10000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 10000-20000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 10000-20000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 10000-20000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 10000-20000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 10000-20000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 10000-20000...
# Retrieved 23 listings on page 6.
# Fetching page 7 for price range 10000-20000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 20000-30000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 20000-30000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 20000-30000...
# Retrieved 190 listings on page 3.
# Fetching page 4 for price range 20000-30000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 30000-130000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 30000-130000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 30000-130000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 30000-130000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 30000-130000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 30000-130000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 30000-130000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 30000-130000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 30000-130000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 30000-130000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 30000-130000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 30000-130000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 30000-130000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 30000-130000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 30000-130000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 30000-130000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 30000-130000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 30000-130000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 30000-130000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 30000-130000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 30000-130000...
# Retrieved 200 listings on page 21.
# Fetching page 22 for price range 30000-130000...
# Retrieved 200 listings on page 22.
# Fetching page 23 for price range 30000-130000...
# Retrieved 200 listings on page 23.
# Fetching page 24 for price range 30000-130000...
# Retrieved 200 listings on page 24.
# Fetching page 25 for price range 30000-130000...
# Retrieved 200 listings on page 25.
# Fetching page 26 for price range 30000-130000...
# Retrieved 200 listings on page 26.
# Fetching page 27 for price range 30000-130000...
# Retrieved 200 listings on page 27.
# Fetching page 28 for price range 30000-130000...
# Retrieved 200 listings on page 28.
# Fetching page 29 for price range 30000-130000...
# Retrieved 200 listings on page 29.
# Fetching page 30 for price range 30000-130000...
# Retrieved 162 listings on page 30.
# Fetching page 31 for price range 30000-130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 130000-230000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 130000-230000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 130000-230000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 130000-230000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 130000-230000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 130000-230000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 130000-230000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 130000-230000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 130000-230000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 130000-230000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 130000-230000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 130000-230000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 130000-230000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 130000-230000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 130000-230000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 130000-230000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 130000-230000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 130000-230000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 130000-230000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 130000-230000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 130000-230000...
# Retrieved 200 listings on page 21.
# Fetching page 22 for price range 130000-230000...
# Retrieved 200 listings on page 22.
# Fetching page 23 for price range 130000-230000...
# Retrieved 200 listings on page 23.
# Fetching page 24 for price range 130000-230000...
# Retrieved 200 listings on page 24.
# Fetching page 25 for price range 130000-230000...
# Retrieved 200 listings on page 25.
# Fetching page 26 for price range 130000-230000...
# Retrieved 200 listings on page 26.
# Fetching page 27 for price range 130000-230000...
# Retrieved 200 listings on page 27.
# Fetching page 28 for price range 130000-230000...
# Retrieved 200 listings on page 28.
# Fetching page 29 for price range 130000-230000...
# Retrieved 200 listings on page 29.
# Fetching page 30 for price range 130000-230000...
# Retrieved 200 listings on page 30.
# Fetching page 31 for price range 130000-230000...
# Retrieved 200 listings on page 31.
# Fetching page 32 for price range 130000-230000...
# Retrieved 200 listings on page 32.
# Fetching page 33 for price range 130000-230000...
# Retrieved 200 listings on page 33.
# Fetching page 34 for price range 130000-230000...
# Retrieved 200 listings on page 34.
# Fetching page 35 for price range 130000-230000...
# Retrieved 200 listings on page 35.
# Fetching page 36 for price range 130000-230000...
# Retrieved 172 listings on page 36.
# Fetching page 37 for price range 130000-230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 230000-330000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 230000-330000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 230000-330000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 230000-330000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 230000-330000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 230000-330000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 230000-330000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 230000-330000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 230000-330000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 230000-330000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 230000-330000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 230000-330000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 230000-330000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 230000-330000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 230000-330000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 230000-330000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 230000-330000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 230000-330000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 230000-330000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 230000-330000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 230000-330000...
# Retrieved 200 listings on page 21.
# Fetching page 22 for price range 230000-330000...
# Retrieved 200 listings on page 22.
# Fetching page 23 for price range 230000-330000...
# Retrieved 200 listings on page 23.
# Fetching page 24 for price range 230000-330000...
# Retrieved 200 listings on page 24.
# Fetching page 25 for price range 230000-330000...
# Retrieved 200 listings on page 25.
# Fetching page 26 for price range 230000-330000...
# Retrieved 200 listings on page 26.
# Fetching page 27 for price range 230000-330000...
# Retrieved 200 listings on page 27.
# Fetching page 28 for price range 230000-330000...
# Retrieved 200 listings on page 28.
# Fetching page 29 for price range 230000-330000...
# Retrieved 200 listings on page 29.
# Fetching page 30 for price range 230000-330000...
# Retrieved 200 listings on page 30.
# Fetching page 31 for price range 230000-330000...
# Retrieved 200 listings on page 31.
# Fetching page 32 for price range 230000-330000...
# Retrieved 200 listings on page 32.
# Fetching page 33 for price range 230000-330000...
# Retrieved 200 listings on page 33.
# Fetching page 34 for price range 230000-330000...
# Retrieved 200 listings on page 34.
# Fetching page 35 for price range 230000-330000...
# Retrieved 200 listings on page 35.
# Fetching page 36 for price range 230000-330000...
# Retrieved 49 listings on page 36.
# Fetching page 37 for price range 230000-330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 330000-430000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 330000-430000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 330000-430000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 330000-430000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 330000-430000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 330000-430000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 330000-430000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 330000-430000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 330000-430000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 330000-430000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 330000-430000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 330000-430000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 330000-430000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 330000-430000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 330000-430000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 330000-430000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 330000-430000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 330000-430000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 330000-430000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 330000-430000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 330000-430000...
# Retrieved 200 listings on page 21.
# Fetching page 22 for price range 330000-430000...
# Retrieved 200 listings on page 22.
# Fetching page 23 for price range 330000-430000...
# Retrieved 200 listings on page 23.
# Fetching page 24 for price range 330000-430000...
# Retrieved 200 listings on page 24.
# Fetching page 25 for price range 330000-430000...
# Retrieved 187 listings on page 25.
# Fetching page 26 for price range 330000-430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 430000-530000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 430000-530000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 430000-530000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 430000-530000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 430000-530000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 430000-530000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 430000-530000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 430000-530000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 430000-530000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 430000-530000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 430000-530000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 430000-530000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 430000-530000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 430000-530000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 430000-530000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 430000-530000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 430000-530000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 430000-530000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 430000-530000...
# Retrieved 200 listings on page 19.
# Fetching page 20 for price range 430000-530000...
# Retrieved 200 listings on page 20.
# Fetching page 21 for price range 430000-530000...
# Retrieved 21 listings on page 21.
# Fetching page 22 for price range 430000-530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 530000-630000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 530000-630000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 530000-630000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 530000-630000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 530000-630000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 530000-630000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 530000-630000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 530000-630000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 530000-630000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 530000-630000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 530000-630000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 530000-630000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 530000-630000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 530000-630000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 530000-630000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 530000-630000...
# Retrieved 200 listings on page 16.
# Fetching page 17 for price range 530000-630000...
# Retrieved 200 listings on page 17.
# Fetching page 18 for price range 530000-630000...
# Retrieved 200 listings on page 18.
# Fetching page 19 for price range 530000-630000...
# Retrieved 144 listings on page 19.
# Fetching page 20 for price range 530000-630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 630000-730000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 630000-730000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 630000-730000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 630000-730000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 630000-730000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 630000-730000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 630000-730000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 630000-730000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 630000-730000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 630000-730000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 630000-730000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 630000-730000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 630000-730000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 630000-730000...
# Retrieved 200 listings on page 14.
# Fetching page 15 for price range 630000-730000...
# Retrieved 200 listings on page 15.
# Fetching page 16 for price range 630000-730000...
# Retrieved 157 listings on page 16.
# Fetching page 17 for price range 630000-730000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 730000-830000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 730000-830000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 730000-830000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 730000-830000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 730000-830000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 730000-830000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 730000-830000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 730000-830000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 730000-830000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 730000-830000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 730000-830000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 730000-830000...
# Retrieved 200 listings on page 12.
# Fetching page 13 for price range 730000-830000...
# Retrieved 200 listings on page 13.
# Fetching page 14 for price range 730000-830000...
# Retrieved 47 listings on page 14.
# Fetching page 15 for price range 730000-830000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 830000-930000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 830000-930000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 830000-930000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 830000-930000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 830000-930000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 830000-930000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 830000-930000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 830000-930000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 830000-930000...
# Retrieved 200 listings on page 9.
# Fetching page 10 for price range 830000-930000...
# Retrieved 200 listings on page 10.
# Fetching page 11 for price range 830000-930000...
# Retrieved 200 listings on page 11.
# Fetching page 12 for price range 830000-930000...
# Retrieved 191 listings on page 12.
# Fetching page 13 for price range 830000-930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 930000-1030000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 930000-1030000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 930000-1030000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 930000-1030000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 930000-1030000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 930000-1030000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 930000-1030000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 930000-1030000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 930000-1030000...
# Retrieved 74 listings on page 9.
# Fetching page 10 for price range 930000-1030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1030000-1130000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1030000-1130000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1030000-1130000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 1030000-1130000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 1030000-1130000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 1030000-1130000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 1030000-1130000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 1030000-1130000...
# Retrieved 63 listings on page 8.
# Fetching page 9 for price range 1030000-1130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1130000-1230000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1130000-1230000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1130000-1230000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 1130000-1230000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 1130000-1230000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 1130000-1230000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 1130000-1230000...
# Retrieved 32 listings on page 7.
# Fetching page 8 for price range 1130000-1230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1230000-1330000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1230000-1330000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1230000-1330000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 1230000-1330000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 1230000-1330000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 1230000-1330000...
# Retrieved 46 listings on page 6.
# Fetching page 7 for price range 1230000-1330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1330000-1430000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1330000-1430000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1330000-1430000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 1330000-1430000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 1330000-1430000...
# Retrieved 7 listings on page 5.
# Fetching page 6 for price range 1330000-1430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1430000-1530000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1430000-1530000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 1430000-1530000...
# Retrieved 170 listings on page 3.
# Fetching page 4 for price range 1430000-1530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1530000-1630000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1530000-1630000...
# Retrieved 195 listings on page 2.
# Fetching page 3 for price range 1530000-1630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1630000-1730000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1630000-1730000...
# Retrieved 75 listings on page 2.
# Fetching page 3 for price range 1630000-1730000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1730000-1830000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1730000-1830000...
# Retrieved 50 listings on page 2.
# Fetching page 3 for price range 1730000-1830000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1830000-1930000...
# Retrieved 190 listings on page 1.
# Fetching page 2 for price range 1830000-1930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 1930000-2030000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 1930000-2030000...
# Retrieved 33 listings on page 2.
# Fetching page 3 for price range 1930000-2030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2030000-2130000...
# Retrieved 81 listings on page 1.
# Fetching page 2 for price range 2030000-2130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2130000-2230000...
# Retrieved 91 listings on page 1.
# Fetching page 2 for price range 2130000-2230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2230000-2330000...
# Retrieved 87 listings on page 1.
# Fetching page 2 for price range 2230000-2330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2330000-2430000...
# Retrieved 71 listings on page 1.
# Fetching page 2 for price range 2330000-2430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2430000-2530000...
# Retrieved 77 listings on page 1.
# Fetching page 2 for price range 2430000-2530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2530000-2630000...
# Retrieved 36 listings on page 1.
# Fetching page 2 for price range 2530000-2630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2630000-2730000...
# Retrieved 46 listings on page 1.
# Fetching page 2 for price range 2630000-2730000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2730000-2830000...
# Retrieved 41 listings on page 1.
# Fetching page 2 for price range 2730000-2830000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2830000-2930000...
# Retrieved 37 listings on page 1.
# Fetching page 2 for price range 2830000-2930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 2930000-3030000...
# Retrieved 43 listings on page 1.
# Fetching page 2 for price range 2930000-3030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3030000-3130000...
# Retrieved 21 listings on page 1.
# Fetching page 2 for price range 3030000-3130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3130000-3230000...
# Retrieved 16 listings on page 1.
# Fetching page 2 for price range 3130000-3230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3230000-3330000...
# Retrieved 17 listings on page 1.
# Fetching page 2 for price range 3230000-3330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3330000-3430000...
# Retrieved 25 listings on page 1.
# Fetching page 2 for price range 3330000-3430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3430000-3530000...
# Retrieved 29 listings on page 1.
# Fetching page 2 for price range 3430000-3530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3530000-3630000...
# Retrieved 9 listings on page 1.
# Fetching page 2 for price range 3530000-3630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3630000-3730000...
# Retrieved 7 listings on page 1.
# Fetching page 2 for price range 3630000-3730000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3730000-3830000...
# Retrieved 4 listings on page 1.
# Fetching page 2 for price range 3730000-3830000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3830000-3930000...
# Retrieved 13 listings on page 1.
# Fetching page 2 for price range 3830000-3930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 3930000-4030000...
# Retrieved 18 listings on page 1.
# Fetching page 2 for price range 3930000-4030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4030000-4130000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 4030000-4130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4130000-4230000...
# Retrieved 5 listings on page 1.
# Fetching page 2 for price range 4130000-4230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4230000-4330000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 4230000-4330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4330000-4430000...
# Retrieved 10 listings on page 1.
# Fetching page 2 for price range 4330000-4430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4430000-4530000...
# Retrieved 4 listings on page 1.
# Fetching page 2 for price range 4430000-4530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4530000-4630000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 4530000-4630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4630000-4730000...
# Retrieved 7 listings on page 1.
# Fetching page 2 for price range 4630000-4730000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4730000-4830000...
# Retrieved 5 listings on page 1.
# Fetching page 2 for price range 4730000-4830000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4830000-4930000...
# Retrieved 4 listings on page 1.
# Fetching page 2 for price range 4830000-4930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 4930000-5030000...
# Retrieved 9 listings on page 1.
# Fetching page 2 for price range 4930000-5030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5030000-5130000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 5030000-5130000.
# Fetching page 1 for price range 5130000-5230000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 5130000-5230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5230000-5330000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 5230000-5330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5330000-5430000...
# Retrieved 5 listings on page 1.
# Fetching page 2 for price range 5330000-5430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5430000-5530000...
# Retrieved 8 listings on page 1.
# Fetching page 2 for price range 5430000-5530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5530000-5630000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 5530000-5630000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5630000-5730000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 5630000-5730000.
# Fetching page 1 for price range 5730000-5830000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 5730000-5830000.
# Fetching page 1 for price range 5830000-5930000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 5830000-5930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 5930000-6030000...
# Retrieved 4 listings on page 1.
# Fetching page 2 for price range 5930000-6030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 6030000-6130000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6030000-6130000.
# Fetching page 1 for price range 6130000-6230000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 6130000-6230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 6230000-6330000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6230000-6330000.
# Fetching page 1 for price range 6330000-6430000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6330000-6430000.
# Fetching page 1 for price range 6430000-6530000...
# Retrieved 4 listings on page 1.
# Fetching page 2 for price range 6430000-6530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 6530000-6630000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6530000-6630000.
# Fetching page 1 for price range 6630000-6730000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6630000-6730000.
# Fetching page 1 for price range 6730000-6830000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 6730000-6830000.
# Fetching page 1 for price range 6830000-6930000...
# Retrieved 6 listings on page 1.
# Fetching page 2 for price range 6830000-6930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 6930000-7030000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 6930000-7030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7030000-7130000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7030000-7130000.
# Fetching page 1 for price range 7130000-7230000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 7130000-7230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7230000-7330000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 7230000-7330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7330000-7430000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7330000-7430000.
# Fetching page 1 for price range 7430000-7530000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 7430000-7530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7530000-7630000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7530000-7630000.
# Fetching page 1 for price range 7630000-7730000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7630000-7730000.
# Fetching page 1 for price range 7730000-7830000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7730000-7830000.
# Fetching page 1 for price range 7830000-7930000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 7830000-7930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 7930000-8030000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 7930000-8030000.
# Fetching page 1 for price range 8030000-8130000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 8030000-8130000.
# Fetching page 1 for price range 8130000-8230000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 8130000-8230000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8230000-8330000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 8230000-8330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8330000-8430000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 8330000-8430000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8430000-8530000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 8430000-8530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8530000-8630000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 8530000-8630000.
# Fetching page 1 for price range 8630000-8730000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 8630000-8730000.
# Fetching page 1 for price range 8730000-8830000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 8730000-8830000.
# Fetching page 1 for price range 8830000-8930000...
# Retrieved 3 listings on page 1.
# Fetching page 2 for price range 8830000-8930000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 8930000-9030000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 8930000-9030000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 9030000-9130000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 9030000-9130000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 9130000-9230000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9130000-9230000.
# Fetching page 1 for price range 9230000-9330000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 9230000-9330000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 9330000-9430000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9330000-9430000.
# Fetching page 1 for price range 9430000-9530000...
# Retrieved 1 listings on page 1.
# Fetching page 2 for price range 9430000-9530000...
# No more data returned; stopping pagination for this price range.
# Fetching page 1 for price range 9530000-9630000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9530000-9630000.
# Fetching page 1 for price range 9630000-9730000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9630000-9730000.
# Fetching page 1 for price range 9730000-9830000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9730000-9830000.
# Fetching page 1 for price range 9830000-9930000...
# No more data returned; stopping pagination for this price range.
# No listings found for price range 9830000-9930000.
# Fetching page 1 for price range 9930000-10030000...
# Retrieved 2 listings on page 1.
# Fetching page 2 for price range 9930000-10030000...
# No more data returned; stopping pagination for this price range.
#
# Raw JSON data saved to 'athome_listings_raw.json'.
# Saved the price selection data to 'price_selection.csv'.
# Data normalized. DataFrame shape: (65404, 99)
# /tmp/ipykernel_30397/1412136614.py:99: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(convert_complex)
# Flattened data saved to SQLite database 'athome_listings.db' in table 'listings'.

# %%
import sqlite3
import pandas as pd

def analyze_database(db_path):
    # Verbindung zur Datenbank herstellen
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # Alle Tabellen in der Datenbank finden
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()

    print("Datenbankstruktur:")
    print("-" * 50)

    for table in tables:
        table_name = table[0]
        print(f"\nTabelle: {table_name}")
        
        # Spalteninformationen für jede Tabelle abrufen
        cursor.execute(f"PRAGMA table_info({table_name})")
        columns = cursor.fetchall()
        
        print("\nSpalten:")
        for col in columns:
            print(f"- {col[1]} ({col[2]})")
        
        # Beispieldaten aus der Tabelle (erste 5 Zeilen)
        try:
            df = pd.read_sql_query(f"SELECT * FROM {table_name} LIMIT 5", conn)
            print("\nBeispieldaten (erste 5 Zeilen):")
            print(df)
        except Exception as e:
            print(f"Fehler beim Lesen der Daten: {e}")
        
        print("-" * 50)

    conn.close()

if __name__ == "__main__":
    db_path = "athome_listings.db"
    try:
        analyze_database(db_path)
    except Exception as e:
        print(f"Fehler beim Öffnen der Datenbank: {e}")
# Out:
# Datenbankstruktur:
# --------------------------------------------------
#
# Tabelle: listings
#
# Spalten:
# - id (INTEGER)
# - externalReference (TEXT)
# - type (TEXT)
# - typeKey (TEXT)
# - typeId (INTEGER)
# - group (TEXT)
# - groupId (TEXT)
# - format (TEXT)
# - isNewBuild (INTEGER)
# - statusBanner (TEXT)
# - createdAt (TEXT)
# - updatedAt (TEXT)
# - soldPrice (TEXT)
# - baselinePrice (TEXT)
# - status (TEXT)
# - transaction (TEXT)
# - publishTo (TEXT)
# - price (REAL)
# - isPriceOnDemand (INTEGER)
# - permalink.de (TEXT)
# - permalink.en (TEXT)
# - permalink.fr (TEXT)
# - address.street (TEXT)
# - address.zip (TEXT)
# - address.city (TEXT)
# - address.district (TEXT)
# - address.department (TEXT)
# - address.region (TEXT)
# - address.suburb (TEXT)
# - address.country (TEXT)
# - address.geohash (TEXT)
# - address.pin.lon (REAL)
# - address.pin.lat (REAL)
# - address.floor (INTEGER)
# - address.display (TEXT)
# - contact.id (REAL)
# - contact.type (TEXT)
# - contact.name (TEXT)
# - contact.email (TEXT)
# - contact.phone (TEXT)
# - contact.mobilePhone (TEXT)
# - contact.receiveRequestBySms (INTEGER)
# - contact.receiveRequestByWhatsapp (INTEGER)
# - contact.allowRemoteAppointment (INTEGER)
# - contact.logo (TEXT)
# - contact.hasExclusiveContract (INTEGER)
# - contact.address.street (TEXT)
# - contact.address.zip (TEXT)
# - contact.address.city (TEXT)
# - contact.address.country (TEXT)
# - contact.address.geohash (TEXT)
# - contact.address.pin.lon (REAL)
# - contact.address.pin.lat (REAL)
# - contact.awardYear (REAL)
# - contact.hasAdvancedForm (INTEGER)
# - contact.hasMultiCallback (INTEGER)
# - contact.isVip (INTEGER)
# - contact.website (TEXT)
# - media.photos (TEXT)
# - media.plan (TEXT)
# - media.video (TEXT)
# - media.virtualVisit (TEXT)
# - media.brochure (TEXT)
# - errors.gateway (TEXT)
# - errors.userReported (TEXT)
# - characteristic.rooms (REAL)
# - characteristic.bedrooms (REAL)
# - characteristic.bathrooms (REAL)
# - characteristic.showers (REAL)
# - characteristic.basement (REAL)
# - characteristic.garages (REAL)
# - characteristic.indoorParking (REAL)
# - characteristic.outdoorParking (REAL)
# - characteristic.surface (REAL)
# - characteristic.groundSurface (REAL)
# - agentId (REAL)
# - contact.agent.id (REAL)
# - contact.agent.photo (TEXT)
# - contact.agent.name (TEXT)
# - contact.agent.email (TEXT)
# - contact.agent.phone (TEXT)
# - contact.agent.receiveRequestBySms (INTEGER)
# - contact.agent.receiveRequestByWhatsapp (INTEGER)
# - contact.agent.allowRemoteAppointment (INTEGER)
# - soldAt (TEXT)
# - availableUnits (REAL)
# - children (TEXT)
# - rooms.min (REAL)
# - rooms.max (REAL)
# - bedrooms.min (REAL)
# - bedrooms.max (REAL)
# - surfaces.min (REAL)
# - surfaces.max (REAL)
# - surfaces.unit (TEXT)
# - prices.min (REAL)
# - prices.max (REAL)
# - prices.unit (TEXT)
# - contact.agent.mobilePhone (TEXT)
# - contact.showForAgent (INTEGER)
#
# Beispieldaten (erste 5 Zeilen):
#         id externalReference       type    typeKey  typeId   group groupId  \
# 0  8444425                      Bedroom    bedroom      21    flat       f
# 1  8013587               478      House      house      25   house       h
# 2  8337387            3830-1     Retail     retail      49  retail       e
# 3  8234785              3501  Apartment  apartment       4    flat       f
# 4  7793642              3651  Apartment  apartment       4    flat       f
#
#       format  isNewBuild statusBanner  ... bedrooms.min bedrooms.max  \
# 0   premiere           0    new-price  ...         None         None
# 1   premiere           0         None  ...         None         None
# 2  highlight           0         None  ...         None         None
# 3  highlight           0         None  ...         None         None
# 4  highlight           0         None  ...         None         None
#
#   surfaces.min surfaces.max surfaces.unit prices.min prices.max  prices.unit  \
# 0         None         None          None       None       None         None
# 1         None         None          None       None       None         None
# 2         None         None          None       None       None         None
# 3         None         None          None       None       None         None
# 4         None         None          None       None       None         None
#
#    contact.agent.mobilePhone contact.showForAgent
# 0                       None                 None
# 1                       None                 None
# 2                       None                 None
# 3                       None                 None
# 4                       None                 None
#
# [5 rows x 99 columns]
# --------------------------------------------------

# %%
import requests
import json
import pandas as pd
import psycopg2  # PostgreSQL driver
from psycopg2.extras import execute_values


# Base URL for the listings endpoint
base_url = "https://www.athome.lu/portal/api/listings"

# This function will page through listings for a given price range.
def fetch_listings(price_gte, price_lte, page_size=200):
    listings = []
    price_results = []
    page = 1
    while True:
        params = {
            "filters[price][gte]": str(price_gte),
            "filters[price][lte]": str(price_lte),
            "pagination[size]": page_size,
            "pagination[page]": page,
            "sort[createdAt]": "desc",
            "site": "athomelu"
        }
        print(f"Fetching page {page} for price range {price_gte}-{price_lte}...")
        response = requests.get(base_url, params=params)

        if response.status_code == 422:
            print("Received 422 Unprocessable Entity error; stopping pagination for this price range.")
            break
        elif response.status_code != 200:
            print(f"Error: Received status code {response.status_code} on page {page} for price range {price_gte}-{price_lte}.")
            break

        data = response.json().get("data", [])
        if not data:
            print("No more data returned; stopping pagination for this price range.")
            break

        listings.extend(data)

        # Save a simplified record for each listing
        for listing in data:
            price_results.append({
                "page": page,
                "price": listing.get("price"),
                "price_from": price_gte,
                "price_to": price_lte
            })
        
        print(f"Retrieved {len(data)} listings on page {page}.")
        page += 1

    return listings, price_results

# List to accumulate full listing objects and simplified price records.
all_listings = []
price_results = []

# Build the list of price ranges.
price_ranges = []

# 1. From 0 to 10,000 in steps of 1,000.
for p in range(0, 10000, 1000):
    price_ranges.append((p, p + 1000))

# 2. From 10,000 to 30,000 in steps of 10,000.
for p in range(10000, 30000, 10000):
    price_ranges.append((p, p + 10000))

# 3. From 30,000 to 10,000,000 in steps of 100,000.
for p in range(30000, 10000000, 100000):
    price_ranges.append((p, p + 100000))

print(f"Total price ranges to query: {len(price_ranges)}")

# Iterate over each price range and collect listings.
for (price_gte, price_lte) in price_ranges:
    listings, prices = fetch_listings(price_gte, price_lte, page_size=200)
    if listings:
        all_listings.extend(listings)
    if prices:
        price_results.extend(prices)
    else:
        print(f"No listings found for price range {price_gte}-{price_lte}.")

# Save the raw JSON data for backup.
with open("athome_listings_raw.json", "w", encoding="utf-8") as f:
    json.dump(all_listings, f, indent=4)
print("\nRaw JSON data saved to 'athome_listings_raw.json'.")

# Save the simplified price data to CSV.
df_price = pd.DataFrame(price_results)
df_price.to_csv("price_selection.csv", index=False, encoding="utf-8")
print("Saved the price selection data to 'price_selection.csv'.")

# Normalize (flatten) the full JSON data.
df = pd.json_normalize(all_listings)
print("Data normalized. DataFrame shape:", df.shape)

# Convert complex types (lists, dicts) to JSON strings so PostgreSQL can store them.
def convert_complex(val):
    if isinstance(val, (list, dict)):
        return json.dumps(val)
    return val

df = df.applymap(convert_complex)

# Connect to PostgreSQL
conn = psycopg2.connect(POSTGRES_URL)
cur = conn.cursor()

# Create the table if it does not exist
cur.execute("""
CREATE TABLE IF NOT EXISTS listings (
    id SERIAL PRIMARY KEY,
    data JSONB
);
""")

# Insert data into PostgreSQL
data_tuples = [(json.dumps(row),) for row in df.to_dict(orient="records")]

execute_values(cur, "INSERT INTO listings (data) VALUES %s", data_tuples)

conn.commit()
cur.close()
conn.close()

print("Data successfully saved to PostgreSQL on Railway! 🚀")
# Out:
# Total price ranges to query: 112
# Fetching page 1 for price range 0-1000...
# Retrieved 200 listings on page 1.
# Fetching page 2 for price range 0-1000...
# Retrieved 200 listings on page 2.
# Fetching page 3 for price range 0-1000...
# Retrieved 200 listings on page 3.
# Fetching page 4 for price range 0-1000...
# Retrieved 200 listings on page 4.
# Fetching page 5 for price range 0-1000...
# Retrieved 200 listings on page 5.
# Fetching page 6 for price range 0-1000...
# Retrieved 200 listings on page 6.
# Fetching page 7 for price range 0-1000...
# Retrieved 200 listings on page 7.
# Fetching page 8 for price range 0-1000...
# Retrieved 200 listings on page 8.
# Fetching page 9 for price range 0-1000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 81
#      79 # Iterate over each price range and collect listings.
#      80 for (price_gte, price_lte) in price_ranges:
# ---> 81     listings, prices = fetch_listings(price_gte, price_lte, page_size=200)
#      82     if listings:
#      83         all_listings.extend(listings)
#
# Cell In[6], line 28, in fetch_listings(price_gte, price_lte, page_size)
#      19 params = {
#      20     "filters[price][gte]": str(price_gte),
#      21     "filters[price][lte]": str(price_lte),
#    (...)
#      25     "site": "athomelu"
#      26 }
#      27 print(f"Fetching page {page} for price range {price_gte}-{price_lte}...")
# ---> 28 response = requests.get(base_url, params=params)
#      30 if response.status_code == 422:
#      31     print("Received 422 Unprocessable Entity error; stopping pagination for this price range.")
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/.python/current/lib/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File ~/.python/current/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.python/current/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.python/current/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/.python/current/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.python/current/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
